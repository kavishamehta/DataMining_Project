# %%
#from nltk.stem import WordNetLemmatizer 
#def process_message(mess):
 #   nopunc =[char for char in mess if char not in string.punctuation]
  #  nopunc=''.join(nopunc)
   # temp= [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    #lemmatizer = WordNetLemmatizer() 
    #words = [lemmatizer.lemmatize(word) for word in temp]   
    #return " ".join(words)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def process_message(message, lower_case = True, stem = True, stop_words = True, gram = 2):
    if lower_case:
        message = message.lower()
    words = word_tokenize(message)
    #words = [char for char in words if char not in string.punctuation]
    #words=''.join(words)
    words = [w for w in words if len(w) > 2]
    if gram > 1:
        w = []
        for i in range(len(words) - gram + 1):
            w += [' '.join(words[i:i + gram])]
        return w
    if stop_words:
        sw = stopwords.words('english')
        words = [word for word in words if word not in sw]
    if stem:
        lemmatizer = WordNetLemmatizer()
        words = [lemmatizer.lemmatize(word) for word in words]   
    return " ".join(words)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re

# %%
pwd
# Out:
# '/content'

# %%
import os
import string
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
print("1 = spam , 0 = not-spam ")
print("\n")
l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part1")
columns=['label','message']
train_df=pd.DataFrame(columns=columns)
train_df=train_df.fillna(0)
for subdir in range(0,len(l)):
    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part1/'+l[subdir])]
    train_df.loc[len(train_df)]=[0,''.join(message)]    #count=count+1
#print(train_df)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# 1 = spam , 0 = not-spam

# %%
l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part2")
for subdir in range(0,len(l)):
    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part2/'+l[subdir])]
    train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part3")
for subdir in range(0,len(l)):
    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part3/'+l[subdir])]
    train_df.loc[len(train_df)]=[0,''.join(message)]   
#print(train_df)

# %%
l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part4")
for subdir in range(0,len(l)):
    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part4/'+l[subdir])]
    train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part5")
for subdir in range(0,len(l)):
    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part5/'+l[subdir])]
    train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
#l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part6")
#for subdir in range(0,len(l)):
 #   message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part6/'+l[subdir])]
  #  train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
#l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part7")
#for subdir in range(0,len(l)):
 #   message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part7/'+l[subdir])]
  #  train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
#l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part8")
#for subdir in range(0,len(l)):
 #   message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part8/'+l[subdir])]
  #  train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
#l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part9")
#for subdir in range(0,len(l)):
#    message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part9/'+l[subdir])]
  #  train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
#l=os.listdir("/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part10")
#for subdir in range(0,len(l)):
 #   message = [line.rstrip() for line in open('/content/drive/My Drive/naive/naivebayes_spam/lingspam_public/bare/part10/'+l[subdir])]
  #  train_df.loc[len(train_df)]=[1,''.join(message)]   
#print(train_df)

# %%
print(train_df)
# Out:
#      label                                            message
# 0        0  Subject: s - > np + npthe discussion of s - > ...
# 1        0  Subject: german corporai am looking for on-lin...
# 2        0  Subject: re : 2 . 882 s - > np np> date : sun ...
# 3        0  Subject: thi , help ! i have to design an expe...
# 4        0  Subject: gent conference" for the listserv " i...
# 5        0  Subject: l2 learning / cultural empathya gradu...
# 6        0  Subject: psycholinguistics teachingfor an unde...
# 7        0  Subject: 2 . 882 s - > np np. . . for me it 's...
# 8        0  Subject: query : causatives in koreancould any...
# 9        0  Subject: job - university of utahthe linguisti...
# 10       0  Subject: job : montrealposte de professeur , e...
# 11       0  Subject: lectureship in linguisticss c h o o l...
# 12       0  Subject: query : email addressesdoes anybody h...
# 13       0  Subject: re : 3 . 378 korean , l2 , psycholing...
# ...

# %%
trainIndex, testIndex = list(), list()
for i in range(train_df.shape[0]):
    if np.random.uniform(0, 1) < 0.75:
        trainIndex += [i]
    else:
        testIndex += [i]
trainData = train_df.loc[trainIndex]
testData = train_df.loc[testIndex]
trainData.reset_index(inplace = True)
trainData.drop(['index'], axis = 1, inplace = True)
#trainData.head()
testData.reset_index(inplace = True)
testData.drop(['index'], axis = 1, inplace = True)
#testData.head()

# %%
from wordcloud import WordCloud
print("Most frequent Spam Words")
spam_words= ' '.join(list(train_df[train_df['label'] == 1]['message']))
spam_wc = WordCloud(width=512,height=512).generate(spam_words)
plt.figure(figsize=(10,8),facecolor='k')
plt.imshow(spam_wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Most frequent Spam Words

# %%
print("Most frequent Non-Spam Words")
ham_words = ' '.join(list(train_df[train_df['label'] == 0]['message']))
ham_wc = WordCloud(width = 512,height = 512).generate(ham_words)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(ham_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()
# Out:
# Most frequent Non-Spam Words

# %%
spam_count_train=(trainData['label']==1).sum()
non_spam_count_train=(trainData['label']==0).sum()
spam_count_test=(testData['label']==1).sum()
non_spam_count_test=(testData['label']==0).sum()

# %%
print("spam train count :" ,spam_count_train)
print("non-spam train count :" ,non_spam_count_train)
print("spam test count :" ,spam_count_test)
print("non-spam test count :" ,non_spam_count_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-365d04c5d07d> in <module>()
# ----> 1 print("spam train count :" ,spam_count_train)
#       2 print("non-spam train count :" ,non_spam_count_train)
#       3 print("spam test count :" ,spam_count_test)
#       4 print("non-spam test count :" ,non_spam_count_test)
#
# NameError: name 'spam_count_train' is not defined

# %%
class SpamClassifier(object):
    
    def __init__(self, trainData, method = 'tf-idf'):
        self.mails, self.labels = trainData['message'], trainData['label']
        self.method = method

    def train(self):
        self.calc_TF_and_IDF()
        if self.method == 'tf-idf':
            self.calc_TF_IDF()
        else:
            self.calc_prob()

    def calc_prob(self):
        self.prob_spam = dict()
        self.prob_ham = dict()
        for word in self.tf_spam:
            self.prob_spam[word] = (self.tf_spam[word] + 1) / (self.spam_words + \
                                                                len(list(self.tf_spam.keys())))
        for word in self.tf_ham:
            self.prob_ham[word] = (self.tf_ham[word] + 1) / (self.ham_words + \
                                                                len(list(self.tf_ham.keys())))
        self.prob_spam_mail, self.prob_ham_mail = self.spam_mails / self.total_mails, self.ham_mails / self.total_mails 


    def calc_TF_and_IDF(self):
        noOfMessages = self.mails.shape[0]
        self.spam_mails, self.ham_mails = self.labels.value_counts()[1], self.labels.value_counts()[0]
        self.total_mails = self.spam_mails + self.ham_mails
        self.spam_words = 0
        self.ham_words = 0
        self.tf_spam = dict()
        self.tf_ham = dict()
        self.idf_spam = dict()
        self.idf_ham = dict()
        for i in range(noOfMessages):
            message_processed = process_message(self.mails[i])
            count = list() #To keep track of whether the word has ocured in the message or not.
                           #For IDF
            for word in message_processed:
                if self.labels[i]:
                    self.tf_spam[word] = self.tf_spam.get(word, 0) + 1
                    self.spam_words += 1
                else:
                    self.tf_ham[word] = self.tf_ham.get(word, 0) + 1
                    self.ham_words += 1
                if word not in count:
                    count += [word]
            for word in count:
                if self.labels[i]:
                    self.idf_spam[word] = self.idf_spam.get(word, 0) + 1
                else:
                    self.idf_ham[word] = self.idf_ham.get(word, 0) + 1
    def calc_TF_IDF(self):
        self.prob_spam = dict()
        self.prob_ham = dict()
        self.sum_tf_idf_spam = 0
        self.sum_tf_idf_ham = 0
        for word in self.tf_spam:
            self.prob_spam[word] = (self.tf_spam[word]) * log((self.spam_mails + self.ham_mails) \
                                                          / (self.idf_spam[word] + self.idf_ham.get(word, 0)))
            self.sum_tf_idf_spam += self.prob_spam[word]
        for word in self.tf_spam:
            self.prob_spam[word] = (self.prob_spam[word] + 1) / (self.sum_tf_idf_spam + len(list(self.prob_spam.keys())))
            
        for word in self.tf_ham:
            self.prob_ham[word] = (self.tf_ham[word]) * log((self.spam_mails + self.ham_mails) \
                                                          / (self.idf_spam.get(word, 0) + self.idf_ham[word]))
            self.sum_tf_idf_ham += self.prob_ham[word]
        for word in self.tf_ham:
            self.prob_ham[word] = (self.prob_ham[word] + 1) / (self.sum_tf_idf_ham + len(list(self.prob_ham.keys())))
            
    
        self.prob_spam_mail, self.prob_ham_mail = self.spam_mails / self.total_mails, self.ham_mails / self.total_mails 
                    
    def classify(self, processed_message):
        pSpam, pHam = 0, 0
        for word in processed_message:                
            if word in self.prob_spam:
                pSpam += log(self.prob_spam[word])
            else:
                if self.method == 'tf-idf':
                    pSpam -= log(self.sum_tf_idf_spam + len(list(self.prob_spam.keys())))
                else:
                    pSpam -= log(self.spam_words + len(list(self.prob_spam.keys())))
            if word in self.prob_ham:
                pHam += log(self.prob_ham[word])
            else:
                if self.method == 'tf-idf':
                    pHam -= log(self.sum_tf_idf_ham + len(list(self.prob_ham.keys()))) 
                else:
                    pHam -= log(self.ham_words + len(list(self.prob_ham.keys())))
            pSpam += log(self.prob_spam_mail)
            pHam += log(self.prob_ham_mail)
        return pSpam >= pHam
    
    def predict(self, testData):
        result = dict()
        for (i, message) in enumerate(testData):
            processed_message = process_message(message)
            result[i] = int(self.classify(processed_message))
        return result

# %%
def metrics(labels, predictions):
    true_pos, true_neg, false_pos, false_neg = 0, 0, 0, 0
    for i in range(len(labels)):
        true_pos += int(labels[i] == 1 and predictions[i] == 1)
        true_neg += int(labels[i] == 0 and predictions[i] == 0)
        false_pos += int(labels[i] == 0 and predictions[i] == 1)
        false_neg += int(labels[i] == 1 and predictions[i] == 0)
    precision = true_pos / (true_pos + false_pos)
    recall = true_pos / (true_pos + false_neg)
    Fscore = 2 * precision * recall / (precision + recall)
    accuracy = (true_pos + true_neg) / (true_pos + true_neg + false_pos + false_neg)

    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F-score: ", Fscore)
    print("Accuracy: ", accuracy)

# %%
print("using Lemmatization")
print("using TF-IDF")
sc_tf_idf = SpamClassifier(trainData, 'tf-idf')
sc_tf_idf.train()
preds_tf_idf = sc_tf_idf.predict(testData['message'])
metrics(testData['label'], preds_tf_idf)

# %%
print("using Lemmatization")
print("using Bag of Words")
sc_bow = SpamClassifier(trainData, 'bow')
sc_bow.train()
preds_bow = sc_bow.predict(testData['message'])
metrics(testData['label'], preds_bow)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pm = process_message('I cant pick the phone right now. Pls send a message')
predict_value=sc_tf_idf.classify(pm)
if (predict_value==True):
    print("message is spam")
else:
    print("Message is a legitimate one")

# %%
pm = process_message('Congratulations ur awarded $500 ')
predict_value=sc_tf_idf.classify(pm)
if (predict_value==True):
    print("message is spam")
else:
    print("Message is a legitimate one")

# %%
pm = process_message('language teacher needed click for details')
predict_value=sc_tf_idf.classify(pm)
if (predict_value==True):
    print("message is spam")
else:
    print("Message is a legitimate one")

# %%
pm = process_message('language teacher job')
predict_value=sc_tf_idf.classify(pm)
if (predict_value==True):
    print("message is spam")
else:
    print("Message is a legitimate one")

# %%
pm = process_message('enter password need bank details also')
predict_value=sc_tf_idf.classify(pm)
if (predict_value==True):
    print("message is spam")
else:
    print("Message is a legitimate one")
